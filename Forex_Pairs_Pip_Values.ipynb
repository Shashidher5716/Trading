# %% [markdown]
# **Pip Calculator**
#
# Currency: **USD**
#
# Size(Lots): **0.05**
#
# PIPS: **100** (1000 Points)

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading Dataset

dt = pd.read_csv("/content/myfxbook.csv")

# %%
# Checking the head of Data

dt.head()
# Out:
#   Currency  Standard Lot    Mini Lot  Micro Lot    Price      PIP v
# 0   AUDCAD    $746.68658   $74.66866   $7.46687  0.87881   $7.46687
# 1   AUDCHF  $1,140.27686  $114.02769  $11.40277  0.57554  $11.40277
# 2   AUDJPY    $702.33597    $70.2336   $7.02336    93.42   $7.02336
# 3   AUDNZD       $609.19     $60.919    $6.0919    1.077    $6.0919
# 4   AUDSGD    $745.65655   $74.56566   $7.45657   0.8795   $7.45657

# %%
# Checking Info of Data

dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Currency      72 non-null     object
#  1   Standard Lot  72 non-null     object
#  2   Mini Lot      72 non-null     object
#  3   Micro Lot     72 non-null     object
#  4   Price         72 non-null     object
#  5   PIP v         72 non-null     object
# dtypes: object(6)
# memory usage: 3.5+ KB

# %%
# Removing Special Symbols

dt['Standard Lot'] = dt['Standard Lot'].str.replace(r'$', '')
dt['Standard Lot'] = dt['Standard Lot'].str.replace(r',', '')
dt['Mini Lot'] = dt['Mini Lot'].str.replace(r'\$', '')
dt['Mini Lot'] = dt['Mini Lot'].str.replace(r'\,', '')
dt['Micro Lot'] = dt['Micro Lot'].str.replace(r'\$', '')
dt['Micro Lot'] = dt['Micro Lot'].str.replace(r'\,', '')
dt['Price'] = dt['Price'].str.replace(r'\$', '')
dt['Price'] = dt['Price'].str.replace(r'\,', '')
dt['PIP v'] = dt['PIP v'].str.replace(r'\$', '')
# Out:
# <ipython-input-5-c723840e6462>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dt['Standard Lot'] = dt['Standard Lot'].str.replace(r'$', '')
# <ipython-input-5-c723840e6462>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   dt['Mini Lot'] = dt['Mini Lot'].str.replace(r'\$', '')
# <ipython-input-5-c723840e6462>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   dt['Mini Lot'] = dt['Mini Lot'].str.replace(r'\,', '')
# <ipython-input-5-c723840e6462>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   dt['Micro Lot'] = dt['Micro Lot'].str.replace(r'\$', '')
# ...

# %%
# Checking the data after removing Special Symbols

dt
# Out:
#    Currency Standard Lot   Mini Lot Micro Lot      Price     PIP v
# 0    AUDCAD    746.68658   74.66866   7.46687    0.87881   7.46687
# 1    AUDCHF   1140.27686  114.02769  11.40277    0.57554  11.40277
# 2    AUDJPY    702.33597    70.2336   7.02336      93.42   7.02336
# 3    AUDNZD       609.19     60.919    6.0919      1.077    6.0919
# 4    AUDSGD    745.65655   74.56566   7.45657     0.8795   7.45657
# ..      ...          ...        ...       ...        ...       ...
# 67   XAUJPY    702.33597    70.2336   7.02336  275428.60   7.02336
# 68   XAUUSD       100000      10000      1000    1934.73     1,000
# 69   XPDUSD       100000      10000      1000    1316.48     1,000
# 70   XPTUSD       100000      10000      1000    1007.15     1,000
# 71   ZARJPY    702.33597    70.2336   7.02336      7.649   7.02336
#
# [72 rows x 6 columns]

# %%
# Checking the value Counts

dt.value_counts()
# Out:
# Currency  Standard Lot  Mini Lot   Micro Lot  Price    PIP v
# AUDCAD    746.68658     74.66866   7.46687    0.87881  7.46687     1
# AUDCHF    1140.27686    114.02769  11.40277   0.57554  11.40277    1
# USDNOK    98.29101      9.8291     0.98291    10.174   0.98291     1
# USDMXN    58.43149      5.84315    0.58431    17.114   0.58431     1
# USDJPY    702.33597     70.2336    7.02336    142.382  7.02336     1
#                                                                   ..
# EURTRY    37.041        3.7041     0.37041    29.631   0.37041     1
# EURSGD    745.65655     74.56566   7.45657    1.472    7.45657     1
# EURSEK    94.09799      9.4098     0.94098    11.663   0.94098     1
# EURPLN    248.15897     24.8159    2.48159    4.423    2.48159     1
# ZARJPY    702.33597     70.2336    7.02336    7.649    7.02336     1
# Length: 72, dtype: int64

# %%
# Checking the Datatypes

dt.dtypes
# Out:
# Currency        object
# Standard Lot    object
# Mini Lot        object
# Micro Lot       object
# Price           object
# PIP v           object
# dtype: object

# %%
# Changing Datatypes

dt['Standard Lot'] = dt['Standard Lot'].astype('float')
dt['Micro Lot'] = dt['Micro Lot'].astype('float')
dt['Price'] = dt['Price'].astype('float')
dt['Mini Lot'] = dt['Mini Lot'].astype('float')

# %%
# Sorting the values

dt.sort_values(by=['Standard Lot', 'Mini Lot'])
# Out:
#    Currency  Standard Lot     Mini Lot   Micro Lot     Price        PIP v
# 54   USDRUB      10.37694      1.03769     0.10377    96.368      0.10377
# 57   USDTHB      28.72573      2.87257     0.28726    34.812      0.28726
# 23   EURTRY      37.04100      3.70410     0.37041    29.631      0.37041
# 35   GBPTRY      37.04100      3.70410     0.37041    34.369      0.37041
# 58   USDTRY      37.04100      3.70410     0.37041    26.997      0.37041
# ..      ...           ...          ...         ...       ...          ...
# 70   XPTUSD  100000.00000  10000.00000  1000.00000  1007.150        1,000
# 61   XAGEUR  109754.00000  10975.40000  1097.54000    21.294     1,097.54
# 65   XAUEUR  109754.00000  10975.40000  1097.54000  1762.550     1,097.54
# 64   XAUCHF  114027.68592  11402.76859  1140.27686  1770.700  1,140.27686
# 66   XAUGBP  127270.00000  12727.00000  1272.70000  1518.200      1,272.7
#
# [72 rows x 6 columns]

# %%
# Sorting the values in reverse order and by giving no to it.

dt.sort_values('Standard Lot', ascending=False).nlargest(50, 'Standard Lot')
# Out:
#    Currency  Standard Lot     Mini Lot   Micro Lot         Price        PIP v
# 66   XAUGBP  127270.00000  12727.00000  1272.70000    1518.20000      1,272.7
# 64   XAUCHF  114027.68592  11402.76859  1140.27686    1770.70000  1,140.27686
# 61   XAGEUR  109754.00000  10975.40000  1097.54000      21.29400     1,097.54
# 65   XAUEUR  109754.00000  10975.40000  1097.54000    1762.55000     1,097.54
# 70   XPTUSD  100000.00000  10000.00000  1000.00000    1007.15000        1,000
# 69   XPDUSD  100000.00000  10000.00000  1000.00000    1316.48000        1,000
# 68   XAUUSD  100000.00000  10000.00000  1000.00000    1934.73000        1,000
# 62   XAGUSD  100000.00000  10000.00000  1000.00000      23.37800        1,000
# 60   XAGAUD   65619.00000   6561.90000   656.19000      35.61600       656.19
# 63   XAUAUD   65619.00000   6561.90000   656.19000    2948.26000       656.19
# 14   EURGBP    1272.70000    127.27000    12.72700       0.86215       12.727
# ...

# %%
# assigning the data

dt_1k = dt.loc[(dt['Standard Lot'] <= 1000)]

# %%
# Checking the count of assigned Data

dt_1k.count()
# Out:
# Currency        55
# Standard Lot    55
# Mini Lot        55
# Micro Lot       55
# Price           55
# PIP v           55
# dtype: int64

# %%
# Checking the Values of assigned Data

dt_1k
# Out:
#    Currency  Standard Lot   Mini Lot  Micro Lot         Price    PIP v
# 0    AUDCAD     746.68658   74.66866    7.46687       0.87881  7.46687
# 2    AUDJPY     702.33597   70.23360    7.02336      93.42000  7.02336
# 3    AUDNZD     609.19000   60.91900    6.09190       1.07700   6.0919
# 4    AUDSGD     745.65655   74.56566    7.45657       0.87950  7.45657
# 5    AUDUSD    1000.00000  100.00000   10.00000       0.65619       10
# 7    CADJPY     702.33597   70.23360    7.02336     106.30900  7.02336
# 8    CHFJPY     702.33597   70.23360    7.02336     162.34100  7.02336
# 9    CHFSGD     745.65655   74.56566    7.45657       1.53000  7.45657
# 10   EURAUD     656.19000   65.61900    6.56190       1.67300   6.5619
# 11   EURCAD     746.68658   74.66866    7.46687       1.47000  7.46687
# 13   EURCZK      45.36217    4.53622    0.45362      24.20600  0.45362
# 15   EURHUF     281.01965   28.10197    2.81020     390.55300   2.8102
# ...

# %%
# Checking the Specific Values

dt.loc[(dt['Standard Lot'] >= 500)]
# Out:
#    Currency  Standard Lot     Mini Lot   Micro Lot         Price        PIP v
# 0    AUDCAD     746.68658     74.66866     7.46687       0.87881      7.46687
# 1    AUDCHF    1140.27686    114.02769    11.40277       0.57554     11.40277
# 2    AUDJPY     702.33597     70.23360     7.02336      93.42000      7.02336
# 3    AUDNZD     609.19000     60.91900     6.09190       1.07700       6.0919
# 4    AUDSGD     745.65655     74.56566     7.45657       0.87950      7.45657
# 5    AUDUSD    1000.00000    100.00000    10.00000       0.65619           10
# 6    CADCHF    1140.27686    114.02769    11.40277       0.65481     11.40277
# 7    CADJPY     702.33597     70.23360     7.02336     106.30900      7.02336
# 8    CHFJPY     702.33597     70.23360     7.02336     162.34100      7.02336
# 9    CHFSGD     745.65655     74.56566     7.45657       1.53000      7.45657
# 10   EURAUD     656.19000     65.61900     6.56190       1.67300       6.5619
# ...

# %%
# applying the Condition to check both values

dt.loc[(dt['Standard Lot'] >= 500) & (dt['Standard Lot'] <= 1000)]
# Out:
#    Currency  Standard Lot   Mini Lot  Micro Lot         Price    PIP v
# 0    AUDCAD     746.68658   74.66866    7.46687       0.87881  7.46687
# 2    AUDJPY     702.33597   70.23360    7.02336      93.42000  7.02336
# 3    AUDNZD     609.19000   60.91900    6.09190       1.07700   6.0919
# 4    AUDSGD     745.65655   74.56566    7.45657       0.87950  7.45657
# 5    AUDUSD    1000.00000  100.00000   10.00000       0.65619       10
# 7    CADJPY     702.33597   70.23360    7.02336     106.30900  7.02336
# 8    CHFJPY     702.33597   70.23360    7.02336     162.34100  7.02336
# 9    CHFSGD     745.65655   74.56566    7.45657       1.53000  7.45657
# 10   EURAUD     656.19000   65.61900    6.56190       1.67300   6.5619
# 11   EURCAD     746.68658   74.66866    7.46687       1.47000  7.46687
# 16   EURJPY     702.33597   70.23360    7.02336     156.27000  7.02336
# 19   EURNZD     609.19000   60.91900    6.09190       1.80100   6.0919
# ...

# %%
# assigning the Values

dt1 = dt.loc[(dt['Price'] <= 100)]

# %%
# This Pairs for 1k

dt1.loc[(dt['Standard Lot'] >= 500) & (dt['Standard Lot'] <= 1000)]
# Out:
#    Currency  Standard Lot   Mini Lot  Micro Lot     Price    PIP v
# 0    AUDCAD     746.68658   74.66866    7.46687   0.87881  7.46687
# 2    AUDJPY     702.33597   70.23360    7.02336  93.42000  7.02336
# 3    AUDNZD     609.19000   60.91900    6.09190   1.07700   6.0919
# 4    AUDSGD     745.65655   74.56566    7.45657   0.87950  7.45657
# 5    AUDUSD    1000.00000  100.00000   10.00000   0.65619       10
# 9    CHFSGD     745.65655   74.56566    7.45657   1.53000  7.45657
# 10   EURAUD     656.19000   65.61900    6.56190   1.67300   6.5619
# 11   EURCAD     746.68658   74.66866    7.46687   1.47000  7.46687
# 19   EURNZD     609.19000   60.91900    6.09190   1.80100   6.0919
# 22   EURSGD     745.65655   74.56566    7.45657   1.47200  7.45657
# 24   EURUSD    1000.00000  100.00000   10.00000   1.09800       10
# 26   GBPAUD     656.19000   65.61900    6.56190   1.94000   6.5619
# 27   GBPCAD     746.68658   74.66866    7.46687   1.70500  7.46687
# ...

# %%
# above 600 - 700

dt1.loc[(dt['Standard Lot'] >= 600) & (dt['Standard Lot'] <= 699)]
# Out:
#    Currency  Standard Lot  Mini Lot  Micro Lot  Price   PIP v
# 3    AUDNZD        609.19    60.919     6.0919  1.077  6.0919
# 10   EURAUD        656.19    65.619     6.5619  1.673  6.5619
# 19   EURNZD        609.19    60.919     6.0919  1.801  6.0919
# 26   GBPAUD        656.19    65.619     6.5619  1.940  6.5619
# 32   GBPNZD        609.19    60.919     6.0919  2.089  6.0919

# %%
# above 700 - 800

dt1.loc[(dt['Standard Lot'] >= 700) & (dt['Standard Lot'] <= 799)]
# Out:
#    Currency  Standard Lot  Mini Lot  Micro Lot     Price    PIP v
# 0    AUDCAD     746.68658  74.66866    7.46687   0.87881  7.46687
# 2    AUDJPY     702.33597  70.23360    7.02336  93.42000  7.02336
# 4    AUDSGD     745.65655  74.56566    7.45657   0.87950  7.45657
# 9    CHFSGD     745.65655  74.56566    7.45657   1.53000  7.45657
# 11   EURCAD     746.68658  74.66866    7.46687   1.47000  7.46687
# 22   EURSGD     745.65655  74.56566    7.45657   1.47200  7.45657
# 27   GBPCAD     746.68658  74.66866    7.46687   1.70500  7.46687
# 34   GBPSGD     745.65655  74.56566    7.45657   1.70800  7.45657
# 37   NOKJPY     702.33597  70.23360    7.02336  13.99100  7.02336
# 39   NZDCAD     746.68658  74.66866    7.46687   0.81581  7.46687
# 41   NZDJPY     702.33597  70.23360    7.02336  86.73400  7.02336
# 43   SEKJPY     702.33597  70.23360    7.02336  13.39500  7.02336
# 45   USDCAD     746.68658  74.66866    7.46687   1.33900  7.46687
# ...

# %%
# above 800 - 900 no data

dt.loc[(dt['Standard Lot'] >= 800) & (dt['Standard Lot'] <= 899)]
# Out:
# Empty DataFrame
# Columns: [Currency, Standard Lot, Mini Lot, Micro Lot, Price, PIP v]
# Index: []

# %%
# above 900 - 1k no data

dt.loc[(dt['Standard Lot'] >= 900) & (dt['Standard Lot'] <= 999)]
# Out:
# Empty DataFrame
# Columns: [Currency, Standard Lot, Mini Lot, Micro Lot, Price, PIP v]
# Index: []

# %%
# above 1k - 2k

dt.loc[(dt['Standard Lot'] >= 1000) & (dt['Standard Lot'] <= 1999)]
# Out:
#    Currency  Standard Lot   Mini Lot  Micro Lot    Price     PIP v
# 1    AUDCHF    1140.27686  114.02769   11.40277  0.57554  11.40277
# 5    AUDUSD    1000.00000  100.00000   10.00000  0.65619        10
# 6    CADCHF    1140.27686  114.02769   11.40277  0.65481  11.40277
# 12   EURCHF    1140.27686  114.02769   11.40277  0.96250  11.40277
# 14   EURGBP    1272.70000  127.27000   12.72700  0.86215    12.727
# 24   EURUSD    1000.00000  100.00000   10.00000  1.09800        10
# 28   GBPCHF    1140.27686  114.02769   11.40277  1.11600  11.40277
# 36   GBPUSD    1000.00000  100.00000   10.00000  1.27300        10
# 40   NZDCHF    1140.27686  114.02769   11.40277  0.53423  11.40277
# 42   NZDUSD    1000.00000  100.00000   10.00000  0.60919        10
# 46   USDCHF    1140.27686  114.02769   11.40277  0.87698  11.40277

# %%
# above 2k - 10k no data

dt.loc[(dt['Standard Lot'] >= 2000) & (dt['Standard Lot'] <= 10000)]
# Out:
# Empty DataFrame
# Columns: [Currency, Standard Lot, Mini Lot, Micro Lot, Price, PIP v]
# Index: []

# %%
# # above 10k - 50k no data

dt.loc[(dt['Standard Lot'] >= 10000) & (dt['Standard Lot'] <= 50000)]
# Out:
# Empty DataFrame
# Columns: [Currency, Standard Lot, Mini Lot, Micro Lot, Price, PIP v]
# Index: []

# %%
# above 50k - 100k => RICH

dt.loc[(dt['Standard Lot'] >= 50000) & (dt['Standard Lot'] <= 100000)]
# Out:
#    Currency  Standard Lot  Mini Lot  Micro Lot     Price   PIP v
# 60   XAGAUD       65619.0    6561.9     656.19    35.616  656.19
# 62   XAGUSD      100000.0   10000.0    1000.00    23.378   1,000
# 63   XAUAUD       65619.0    6561.9     656.19  2948.260  656.19
# 68   XAUUSD      100000.0   10000.0    1000.00  1934.730   1,000
# 69   XPDUSD      100000.0   10000.0    1000.00  1316.480   1,000
# 70   XPTUSD      100000.0   10000.0    1000.00  1007.150   1,000

# %%
# above 100k - 10M => SUPER RICH

dt.loc[(dt['Standard Lot'] >= 100000) & (dt['Standard Lot'] <= 1000000)]
# Out:
#    Currency  Standard Lot     Mini Lot   Micro Lot     Price        PIP v
# 61   XAGEUR  109754.00000  10975.40000  1097.54000    21.294     1,097.54
# 62   XAGUSD  100000.00000  10000.00000  1000.00000    23.378        1,000
# 64   XAUCHF  114027.68592  11402.76859  1140.27686  1770.700  1,140.27686
# 65   XAUEUR  109754.00000  10975.40000  1097.54000  1762.550     1,097.54
# 66   XAUGBP  127270.00000  12727.00000  1272.70000  1518.200      1,272.7
# 68   XAUUSD  100000.00000  10000.00000  1000.00000  1934.730        1,000
# 69   XPDUSD  100000.00000  10000.00000  1000.00000  1316.480        1,000
# 70   XPTUSD  100000.00000  10000.00000  1000.00000  1007.150        1,000

# %%
# above 11M - 15M => Ultra RICH

dt.loc[(dt['Standard Lot'] >= 110000) & (dt['Standard Lot'] <= 150000)]
# Out:
#    Currency  Standard Lot     Mini Lot   Micro Lot   Price        PIP v
# 64   XAUCHF  114027.68592  11402.76859  1140.27686  1770.7  1,140.27686
# 66   XAUGBP  127270.00000  12727.00000  1272.70000  1518.2      1,272.7

# %%
# above 15M - 20M no data

dt.loc[(dt['Standard Lot'] >= 150000) & (dt['Standard Lot'] <= 200000)]
# Out:
# Empty DataFrame
# Columns: [Currency, Standard Lot, Mini Lot, Micro Lot, Price, PIP v]
# Index: []
